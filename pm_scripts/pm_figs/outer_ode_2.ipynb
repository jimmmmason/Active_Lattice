# %%
cd("/home/jm2386/Active_Lattice/")
using DrWatson
@quickactivate "Active_Lattice"
include("/home/jm2386/Active_Lattice/src/pm_pdes.jl");
include("/home/jm2386/Active_Lattice/src/pm_sims.jl");
include("/home/jm2386/Active_Lattice/src/pm_plot.jl");
include("/home/jm2386/Active_Lattice/src/Hetrocline.jl");
# Out:
# v3.0
# v4.0

# %%
Lx, Nx, ϕa, ϕp, v0 = 100.0, 1024, 0.32, 0.3, 7.5
param, p2 = get_outer_param_2(Lx,Nx,ϕa,ϕp,v0)
f,u,c = load_out_2(Lx,Nx,ϕa,ϕp,v0)
# f,u,c = solve_out_2(Lx,Nx,ϕa,ϕp,v0,u; tol = 1e-9)
err, avmag, c = check_u(u,p2);
print("ϕa,ϕp=($(ϕa),$(ϕp)): c=$(c), avmag=$(avmag), err=$(err)")
# Out:
# ϕa,ϕp=(0.32,0.3): c=2.49279637705257, avmag=0.26288164643043055, err=2.6289934673684456e-9

# %%
Lx, Nx, ϕa, ϕp, v0 = 100.0, 1024, 0.52, 0.32, 7.5
param, p2 = get_outer_param_2(Lx,Nx,ϕa,ϕp,v0)
f,u,c = load_out_2(Lx,Nx,ϕa,ϕp,v0)
# f,u,c = solve_out_2(Lx,Nx,ϕa,ϕp,v0,u; tol = 1e-9)
err, avmag, c = check_u(u,p2);
print("ϕa,ϕp=($(ϕa),$(ϕp)): c=$(c), avmag=$(avmag), err=$(err)")
# Out:
# ϕa,ϕp=(0.52,0.32): c=1.5436408740154217, avmag=-0.0004883022725854063, err=1.8840484727888906e-13

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f; c=c, point = 100)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f; c=c, point = 100)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f; c=c, point = 100)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
axs[1].axis([0.45, 0.5, 0.5, 1.0])
axs[1].set_aspect((0.05/(0.5)))
fig.tight_layout()
display(fig)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

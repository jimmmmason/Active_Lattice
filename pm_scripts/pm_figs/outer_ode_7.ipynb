# %%
cd("/home/jm2386/Active_Lattice/")
using DrWatson
@quickactivate "Active_Lattice"
include("/home/jm2386/Active_Lattice/src/pm_pdes.jl");
include("/home/jm2386/Active_Lattice/src/pm_sims.jl");
include("/home/jm2386/Active_Lattice/src/pm_plot.jl");
include("/home/jm2386/Active_Lattice/src/Hetrocline.jl");
# Out:
# v3.0
# v4.0
# WARNING: method definition for #h0#128 at /home/jm2386/Active_Lattice/src/Hetrocline.jl:57 declares type variable N but does not use it.
# WARNING: method definition for #h0#128 at /home/jm2386/Active_Lattice/src/Hetrocline.jl:57 declares type variable V but does not use it.
# WARNING: method definition for #h0#128 at /home/jm2386/Active_Lattice/src/Hetrocline.jl:57 declares type variable T but does not use it.

# %%
## outer 6 
function ff_out_7(F,u,p; atol = 1e-12)
    DT, v0, DR, Δx, Nx, Lx, ϕa, ϕp, ind, γ, ϕaL, ϕaR, ϕL, ϕR = p
        global ρ,ρa,m,ep
        local c
        ρ  = u[(0*Nx+1):1:(1*Nx)]
        ρa = u[(1*Nx+1):1:(2*Nx)]
        c  = u[end]

        for i in 2:(ind-1)
            F[i-1]      = rho_out_eq_2(ρ,ρa,c,i; p = p) - rho_out_eq_2(ρ,ρa,c,1; p = p)
            F[Nx-3+i]   = act_out_eq_2(ρ,ρa,c,i; p = p) - act_out_eq_2(ρ,ρa,c,1; p = p)
        end

        for i in (ind+1):1:(Nx-1)
            F[i-1]      = rho_out_eq_2(ρ,ρa,c,i; p = p) - rho_out_eq_2(ρ,ρa,c,1; p = p)
            F[Nx-3+i]   = act_out_eq_2(ρ,ρa,c,i; p = p) - act_out_eq_2(ρ,ρa,c,1; p = p)
        end

        ind1 = 1
        γ_end = (-ρa[end].+1)./(-ρ[end].+1)
        γ_srt = (-ρa[ind1].+1)./(-ρ[ind1].+1)
        F[ind-1]    = gg0.(ρ[end], γ_end; Pe = v0) - gg0.(ρ[ind1], γ_srt; Pe = v0)
        F[Nx-3+ind] = (hhh0.(ρ[end], γ_end; Pe = v0, atol = atol) - hhh0.(ρ[ind1], γ_srt; Pe = v0, atol = atol))./10
        F[2*Nx+1]   = γ_end .- γ_srt

        ind1 = ind +1 
        F[2*Nx-3] = ρa[ind] - ϕaL
        F[2*Nx-2] = ρa[ind1] - ϕaR
        F[2*Nx-1] = ρ[ind] - ϕL
        F[2*Nx]   = ρ[ind1] - ϕR 
end

function load_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
    param, ps = get_outer_param_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
    filename = outer_save_name_7(param,ind,γ)
    data = load(filename)
    @unpack f, c = data
    u = get_out_u(f,c,Lx)
    return f, u, c
end

using NonlinearSolve, DifferentialEquations
function solve_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ,u0; tol = 1e-8, maxiters = 100)
    param, p = get_outer_param_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
    # Set problem
    prob = NonlinearProblem(ff_out_7,u0, p; abstol = tol, reltol =  tol, maxiters = maxiters);
    sol  = solve(prob)
    #
    # Save
        u = sol.u
        f = get_out_f(u,param)
        c = u[end]/Lx
        filename    = outer_save_name_7(param,ind,γ)
        data        = Dict("f" => f, "c" => c)
        safesave(filename,data)
    #
    return f, u, c
end

function get_outer_param_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
    param = get_stretch_param(Lx)
    name = "outer_sol_7"
    Δx = Lx/Nx
    DT = DR = 1.0
    ϕaL, ϕaR, ϕL, ϕR = get_BC(γ,v0;initial_Δ = 1e-6, tol = 1e-8 )
    @pack! param = Lx,Nx,ϕa,ϕp,v0,name,Δx
    ps = DT, v0, DR, Δx, Nx, Lx, ϕa, ϕp, ind, γ, ϕaL, ϕaR, ϕL, ϕR
    return param, ps
end

function outer_save_name_7(param,ind,γ)
    @unpack DT, v0, DR, Nx, Lx, name, ϕa, ϕp = param
    return "/store/DAMTP/jm2386/Active_Lattice/data/pm_pdes_pro/outer_sol/$(name)/[DT,v0,DR,Nx,ind,γ]=$([DT,v0,DR,Nx,ind,γ]).jld2"
end

function check_u_7(u,ps)
    DT, v0, DR, Δx, Nx, Lx, ϕa, ϕp, ind, γ, ϕaL, ϕaR, ϕL, ϕR = ps
    param, _ = get_outer_param_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
    F = zeros(2*Nx+1)
    ff_out_7(F,u,ps)
    f = get_out_f(u,param)
    avmag = Lx*sum(f[:,2]-f[:,1])/Nx
    return maximum(abs.(F)), argmax(abs.(F)), avmag, u[end]/Lx
end

function increase_ind_7(u,ps)
    DT, v0, DR, Δx, Nx, Lx, ϕa, ϕp, ind, γ, ϕaL, ϕaR, ϕL, ϕR = ps
    i = ind
    u[i+1] = u[i]
    i = Nx + i 
    u[i+1] = u[i]
    ps = DT, v0, DR, Δx, Nx, Lx, ϕa, ϕp, (ind+1), γ, ϕaL, ϕaR, ϕL, ϕR
    return u, ps
end

function decrease_ind_7(u,ps)
    DT, v0, DR, Δx, Nx, Lx, ϕa, ϕp, ind, γ, ϕaL, ϕaR, ϕL, ϕR = ps
    i = ind
    u[i] = u[i+1]
    i = Nx + i
    u[i] = u[i+1]
    ps = DT, v0, DR, Δx, Nx, Lx, ϕa, ϕp, (ind-1), γ, ϕaL, ϕaR, ϕL, ϕR
    return u, ps
end

function increase_inds(u,ps,n)
    for i in 1:n
        u, ps = increase_ind_7(u,ps)
    end
    return u, ps
end

function decrease_inds(u,ps,n)
    for i in 1:n
        u, ps = decrease_ind_7(u,ps)
    end
    return u, ps
end
#
# Out:
# decrease_inds (generic function with 1 method)

# %%
# Lx,Nx,ϕa,ϕp,v0,ind,γ = 100.0, 1024, 0.3, 0.3, 7.5, 56, 1.7369414724789993
Lx,Nx,ϕa,ϕp,v0,ind,γ = 100.0, 1024, 0.3, 0.3, 7.5, 680, 1.75
# Lx,Nx,ϕa,ϕp,v0,ind,γ = 100.0, 1024, 0.3, 0.3, 7.5, 200, 1.7
param, ps = get_outer_param_6(Lx,Nx,ϕa,ϕp,v0,ind,γ)
f,u,c = load_out_6(Lx,Nx,ϕa,ϕp,v0,ind,γ)
# f,u,c = solve_out_6(Lx,Nx,ϕa,ϕp,v0,ind,γ,u; tol = 1e-8, maxiters =10)
# check densities
        ϕp = sum(f)/Nx-sum(f[:,1:2])/Nx
        if ϕp ≈ ( param["ϕp"] )
            ϕp = param["ϕp"]
        else
            ϕp = d2(ϕp)
        end
        ϕa = sum(f[:,1:2])/Nx
        if ϕa ≈ ( param["ϕa"] )
            ϕa = param["ϕa"]
        else
            ϕa = d2(ϕa)
        end
#
rhodiff = u[ind+1] - u[ind]
err, erri, avmag, cep = check_u_6(u,ps);
println("ϕa,ϕp=($(ϕa),$(ϕp)): rhodiff=$(rhodiff), c =$(c), avmag=$(avmag), err=$(err),$(erri), ind=$(ind)")
# Out:
# ϕa,ϕp=(0.56,0.19): rhodiff=0.24482792651711727, c =0.0003412351532876705, avmag=0.21272851038171237, err=3.9489245207136037e-13,1544, ind=680

# %%
ρ  = u[(0*Nx+1):1:(1*Nx)]
ρa  = u[(1*Nx+1):1:(2*Nx)]
γ_end = (-ρa[ind].+1)./(-ρ[ind].+1)
# Out:
# 1.8197786832206424

# %%
Lx,Nx,ϕa,ϕp,v0,ind,γ = 100.0, 1024, 0.3, 0.3, 7.5, 680, 1.85
# Lx,Nx,ϕa,ϕp,v0,ind,γ = 100.0, 1024, 0.3, 0.3, 7.5, 440, 1.85
# Lx,Nx,ϕa,ϕp,v0,ind,γ = 100.0, 1024, 0.3, 0.3, 7.5, 520, 1.815 #1.85
# Lx,Nx,ϕa,ϕp,v0,ind,γ = 100.0, 1024, 0.3, 0.3, 7.5, 800, 1.5
param, ps = get_outer_param_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
f,u,c = load_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
# f,u,c = solve_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ,u; tol = 1e-14, maxiters = 10)
# check densities
        ϕp = sum(f)/Nx-sum(f[:,1:2])/Nx
        ϕa = sum(f[:,1:2])/Nx
#
rhodiff = u[ind+1] - u[ind]
err, erri, avmag, cep = check_u_7(u,ps);
println("ϕa,ϕp=($(ϕa),$(ϕp)): rhodiff=$(rhodiff), c =$(c), avmag=$(avmag), err=$(err),$(erri), ind=$(ind)")
# Out:
# ϕa,ϕp=(0.5622239078768436,0.19227227375236922): rhodiff=0.23129452643451887, c =0.0006204388855358148, avmag=0.2189156165571453, err=4.040309753428062e-13,1500, ind=680

# %%
ρ  = u[(0*Nx+1):1:(1*Nx)]
ρa  = u[(1*Nx+1):1:(2*Nx)]
γ_end = (-ρa[end].+1)./(-ρ[end].+1)
# Out:
# 1.8125659229833786

# %%
# for i in 1:7
    # global u, ps, f,c, DT, v0, DR, Δx, Nx, Lx, ϕa, ϕp, ind, γ, ϕaL, ϕaR, ϕL, ϕR
    # u,ps = increase_inds(u,ps,4)
    # u,ps = decrease_inds(u,ps,2)
    DT, v0, DR, Δx, Nx, Lx, ϕa,ϕp, ind, γ, ϕaL, ϕaR, ϕL, ϕR = ps
    γ = 2.21
    # ind = 701
    f,u,c = solve_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ,u; tol = 1e-8, maxiters = 10)
    # f,u,c = solve_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ,u; tol = 1e-8, maxiters = 20)
    # check densities
            ϕp = sum(f)/Nx-sum(f[:,1:2])/Nx
            if ϕp ≈ ( param["ϕp"] )
                ϕp = param["ϕp"]
            else
                ϕp = d2(ϕp)
            end
            ϕa = sum(f[:,1:2])/Nx
            if ϕa ≈ ( param["ϕa"] )
                ϕa = param["ϕa"]
            else
                ϕa = d2(ϕa)
            end
    #
    param, ps = get_outer_param_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
    err, erri, avmag, cep = check_u_7(u,ps);
    rhodiff = u[ind+1] - u[ind]
    ϕp = sum(f)/Nx-sum(f[:,1:2])/Nx
    ϕa = sum(f[:,1:2])/Nx
    normf = sqrt(sum( (f[:,1] .- ϕa/2).^2 + (f[:,2] .- ϕa/2).^2 + (f[:,3] .- ϕp).^2)/Nx)
    println("ϕa,ϕp=($(d2(ϕa)),$(d2(ϕp))): c = $(c) normf=$(normf), err=$(err),$(erri), ind=$(ind)") #hodiff=$(rhodiff), cep =$(cep), avmag=$(avmag),
# end
# Out:
# ϕa,ϕp=(0.72,0.16): c = 0.007747205682794262 normf=0.11255315865796459, err=8.609528645564524e-10,205, ind=208

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f; c=c, point = ind-Nx÷2)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %%
ρ  = u[(0*Nx+1):1:(1*Nx)]
ρa  = u[(1*Nx+1):1:(2*Nx)]
γ = (-ρa[end].+1)./(-ρ[end].+1)
ϕp = sum(f)/Nx-sum(f[:,1:2])/Nx
ϕa = sum(f[:,1:2])/Nx
ϕ = ϕa+ϕp
# Out:
# 0.8767566328269738

# %%
speeds = Dict{String,Any}()
for ind in [440, 520, 680]
    speeds["$(ind)"] = Set()
end

# %%
push!(speeds["$(ind)"],(0.0,0.0))
# Out:
# Set{Any} with 1 element:
#   (0.0, 0.0)

# %%
using PyPlot, LaTeXStrings
fig, ax = subplots(1,1,figsize=(5,5))
rc("text", usetex=true)

markers = ["x","o","s"]
colours = ["tab:orange", "tab:purple", "tab:blue"]
Lx,Nx,ϕa,ϕp,v0 = 100.0, 1024, 0.3, 0.3, 7.5
speeds = Dict{String,Any}()
for ind in [440, 520, 680]
    speeds["$(ind)"] = Set()
end

for (i,ind) in enumerate([440, 520, 680])
    for γ in 1.84:-0.001:1.785
        try 
            param, ps = get_outer_param_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
            f,u,c = load_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
            err, erri, avmag, cep = check_u_7(u,ps)
            if (err<1e-8)&&(c>1e-8)
                push!(speeds["$(ind)"],(γ,c))
                ax.scatter(γ,c; marker = markers[i], color = colours[i])
            end
        catch
            # try
            #     f,u,c = solve_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ,u; tol = 1e-12, maxiters = 10)
            #     if (err<1e-8)&&(c>0)
            #         ax.scatter(γ,c; marker = markers[i], color = colours[i])
            #     end
            # catch
            # end
        end
    end
end
for (i,ind) in enumerate([440, 520, 680])
    for γ in 1.85:0.01:2.0
        try
            param, ps = get_outer_param_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
            f,u,c = load_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
            err, erri, avmag, cep = check_u_7(u,ps)
            if (err<1e-8)&&(c>0)
                push!(speeds["$(ind)"],(γ,c))
                ax.scatter(γ,c; marker = markers[i], color = colours[i])
            end
        catch
            # try
            #     f,u,c = solve_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ,u; tol = 1e-12, maxiters = 10)
            #     if (err<1e-8)&&(c>0)
            #         ax.scatter(γ,c; marker = markers[i], color = colours[i])
            #     end
            # catch
            # end
        end
    end
end

# %%
Pe = 7.5
file_name = "/store/DAMTP/jm2386/Active_Lattice/data/pm_pdes_pro/outer_7_speeds/Pe=$(Pe).jld2"
data = Dict{String,Any}()
@pack! data = speeds
safesave(file_name,data)

# %%
Pe = 7.5
file_name = "/store/DAMTP/jm2386/Active_Lattice/data/pm_pdes_pro/outer_7_speeds/Pe=$(Pe).jld2"

data = load(file_name)
@unpack speeds = data
# Out:
# Dict{String, Any} with 1 entry:
#   "speeds" => Dict{String, Any}("440"=>Set(Any[(1.829, 6.53102e-5), (1.94, 0.00…

# %%
using PyPlot, LaTeXStrings
fig, ax = subplots(1,1,figsize=(5,5))
rc("text", usetex=true)
font = 12

# markers = ["x","o","s"]
colours = ["tab:orange", "tab:purple", "tab:blue"]

for (i,ind) in enumerate([440, 520, 680])
    label = latexstring("\$ \\bar x = $(d2(ind/1024))\$")
    XY = hcat(collect.(sort(collect(speeds["$(ind)"]); by= x->x[1]))...)
    ax.plot(XY[1,:], XY[2,:]; color = colours[i], label = label)
end

ax.tick_params(direction = "in", labelsize = font)
ax.legend(fontsize = font, edgecolor = "white")
ax.set_xlabel(L"\gamma",fontsize=font)
ax.set_ylabel(L"\bar c", fontsize=font)
ax.axis([1.75,2.0,0,2e-3])
display(fig)
# Out:
# Figure(PyObject <Figure size 500x500 with 1 Axes>)

# %%
v0 = 7.5
fig_name = "mips_to_TP_point"
pathname = "/store/DAMTP/jm2386/Active_Lattice/plots/pm_eigen/$(fig_name)";
mkpath(pathname)
filename = "/store/DAMTP/jm2386/Active_Lattice/plots/pm_eigen/$(fig_name)/Pe=$(v0).pdf";
PyPlot.savefig(filename,dpi = 100, format = "pdf") #bbox_extra_artists=( ldg,)

# %%
# Out:
# Figure(PyObject <Figure size 500x500 with 1 Axes>)

# %%
# Lx,Nx,ϕa,ϕp,v0,ϕ,γ = 100.0, 1024, 0.3, 0.3, 7.5, 0.38, 1.24
# Lx,Nx,ϕa,ϕp,v0,ϕ,γ = 100.0, 1024, 0.3, 0.3, 7.5, 0.89, 2.06
# Lx,Nx,ϕa,ϕp,v0,ϕ,γ = 100.0, 1024, 0.3, 0.3, 7.5, 0.8, 1.55
# Lx,Nx,ϕa,ϕp,v0,ϕ,γ = 100.0, 1024, 0.3, 0.3, 7.5, 0.8, 2.2
Lx,Nx,ϕa,ϕp,v0,ϕ,γ = 100.0, 1024, 0.3, 0.3, 7.5, 0.88, 1.7
param, ps = get_outer_param_5(Lx,Nx,ϕa,ϕp,v0,ϕ,γ);
# f,u,c = load_out_5(Lx,Nx,ϕa,ϕp,v0,ϕ,γ)
f,u,c = solve_out_5(Lx,Nx,ϕa,ϕp,v0,ϕ,γ,u; tol = 1e-8, maxiters = 20)
# check densities
        ϕp = sum(f)/Nx-sum(f[:,1:2])/Nx
        if ϕp ≈ ( param["ϕp"] )
            ϕp = param["ϕp"]
        else
            ϕp = d2(ϕp)
        end
        ϕa = sum(f[:,1:2])/Nx
        if ϕa ≈ ( param["ϕa"] )
            ϕa = param["ϕa"]
        else
            ϕa = d2(ϕa)
        end
#
err, erri, avmag, cep = check_u_5(u,ps);
ϕp = sum(f)/Nx-sum(f[:,1:2])/Nx
ϕa = sum(f[:,1:2])/Nx
normf = sqrt(sum( (f[:,1] .- ϕa/2).^2 + (f[:,2] .- ϕa/2).^2 + (f[:,3] .- ϕp).^2)/Nx)
print("ϕa,ϕp=($(ϕa),$(ϕp)): norm = $(normf), c=$(c), avmag=$(avmag), err=$(err)")
# Out:
# ϕa,ϕp=(0.7173637027517265,0.1594347641577547): norm = 0.10657447406696939, c=0.008251632428834517, avmag=0.22307683187336555, err=0.003201533090519071

# %%
erri
# Out:
# 2049

# %%
ind = argmax(f[:,2]-f[:,1])- Nx÷2 + 6
γ = 2.2
# Out:
# 2.2

# %%
# Lx,Nx,ϕa,ϕp,v0,ind,γ = 100.0, 1024, 0.3, 0.3, 7.5, 200, 2.132
# Lx,Nx,ϕa,ϕp,v0,ind,γ = 100.0, 1024, 0.3, 0.3, 7.5, 800, 1.5
param, ps = get_outer_param_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
# f,u,c = load_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
f,u,c = solve_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ,u; tol = 1e-8, maxiters = 10)
# check densities
        ϕp = sum(f)/Nx-sum(f[:,1:2])/Nx
        if ϕp ≈ ( param["ϕp"] )
            ϕp = param["ϕp"]
        else
            ϕp = d2(ϕp)
        end
        ϕa = sum(f[:,1:2])/Nx
        if ϕa ≈ ( param["ϕa"] )
            ϕa = param["ϕa"]
        else
            ϕa = d2(ϕa)
        end
#
rhodiff = u[ind+1] - u[ind]
err, erri, avmag, cep = check_u_7(u,ps);
println("ϕa,ϕp=($(ϕa),$(ϕp)): rhodiff=$(rhodiff), c =$(c), avmag=$(avmag), err=$(err),$(erri), ind=$(ind)")
# Out:
# DomainError with NaN:
#
# integrand produced NaN in the interval (0.0, NaN)
#
#
#
# Stacktrace:
#
#   [1] evalrule(f::var"#f#619"{Float64}, a::Float64, b::Float64, x::Vector{Float64}, w::Vector{Float64}, gw::Vector{Float64}, nrm::typeof(norm))
#
#     @ QuadGK ~/.julia/packages/QuadGK/OtnWt/src/evalrule.jl:37
#
#   [2] #6
#
#     @ ~/.julia/packages/QuadGK/OtnWt/src/adapt.jl:15 [inlined]
#
#   [3] ntuple
#
#     @ ./ntuple.jl:48 [inlined]
#
#   [4] do_quadgk(f::var"#f#619"{Float64}, s::Tuple{Float64, Float64}, n::Int64, atol::Float64, rtol::Float64, maxevals::Int64, nrm::typeof(norm), segbuf::Nothing)
#
#     @ QuadGK ~/.julia/packages/QuadGK/OtnWt/src/adapt.jl:13
#
#   [5] #50
#
#     @ ~/.julia/packages/QuadGK/OtnWt/src/adapt.jl:253 [inlined]
#
#   [6] handle_infinities(workfunc::QuadGK.var"#50#51"{Float64, Float64, Int64, Int64, typeof(norm), Nothing}, f::var"#f#619"{Float64}, s::Tuple{Float64, Float64})
#
#     @ QuadGK ~/.julia/packages/QuadGK/OtnWt/src/adapt.jl:145
#
#   [7] #quadgk#49
#
#     @ ~/.julia/packages/QuadGK/OtnWt/src/adapt.jl:252 [inlined]
#
#   [8] quadgk
#
#     @ ~/.julia/packages/QuadGK/OtnWt/src/adapt.jl:250 [inlined]
#
#   [9] R(ρ::Float64; rtol::Float64, tol::Float64)
#
#     @ Main ~/Active_Lattice/src/Hetrocline.jl:23
#
#  [10] #43
#
#     @ ./broadcast.jl:1327 [inlined]
#
#  [11] _broadcast_getindex_evalf
#
#     @ ./broadcast.jl:709 [inlined]
#
#  [12] _broadcast_getindex
#
#     @ ./broadcast.jl:682 [inlined]
#
#  [13] getindex
#
#     @ ./broadcast.jl:636 [inlined]
#
#  [14] copy
#
#     @ ./broadcast.jl:918 [inlined]
#
#  [15] materialize
#
#     @ ./broadcast.jl:903 [inlined]
#
#  [16] hhh0(ρ::Float64, γ::Float64; Pe::Float64, atol::Float64, log_tol::Float64)
#
#     @ Main ~/Active_Lattice/src/pm_plot.jl:1021
#
#  [17] hhh0
#
#     @ ~/Active_Lattice/src/pm_plot.jl:1017 [inlined]
#
#  [18] #43
#
#     @ ./broadcast.jl:1327 [inlined]
#
#  [19] _broadcast_getindex_evalf
#
#     @ ./broadcast.jl:709 [inlined]
#
#  [20] _broadcast_getindex
#
#     @ ./broadcast.jl:682 [inlined]
#
#  [21] getindex
#
#     @ ./broadcast.jl:636 [inlined]
#
#  [22] copy
#
#     @ ./broadcast.jl:918 [inlined]
#
#  [23] materialize(bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{0}, Nothing, Base.Broadcast.var"#43#44"{@Kwargs{Pe::Float64, atol::Float64}, typeof(hhh0)}, Tuple{Float64, Float64}})
#
#     @ Base.Broadcast ./broadcast.jl:903
#
#  [24] ff_out_7(F::Matrix{Float64}, u::Matrix{Float64}, p::Tuple{Float64, Float64, Float64, Float64, Int64, Float64, Float64, Float64, Int64, Vararg{Float64, 5}}; atol::Float64)
#
#     @ Main ~/Active_Lattice/pm_scripts/pm_figs/outer_ode_7.ipynb:24
#
#  [25] ff_out_7
#
#     @ ~/Active_Lattice/pm_scripts/pm_figs/outer_ode_7.ipynb:2 [inlined]
#
#  [26] NonlinearFunction
#
#     @ ~/.julia/packages/SciMLBase/GPp9w/src/scimlfunctions.jl:2185 [inlined]
#
#  [27] evaluate_f!
#
#     @ ~/.julia/packages/NonlinearSolve/R8LAH/src/internal/helpers.jl:17 [inlined]
#
#  [28] __step!(cache::NonlinearSolve.ApproximateJacobianSolveCache{false, :LineSearch, true, false, Matrix{Float64}, Matrix{Float64}, Matrix{Float64}, Tuple{Float64, Float64, Float64, Float64, Int64, Float64, Float64, Float64, Int64, Vararg{Float64, 5}}, Matrix{Float64}, Diagonal{Float64, Vector{Float64}}, ApproximateJacobianSolveAlgorithm{false, :Klement, NoLineSearch, Missing, NewtonDescent{Nothing, typeof(NonlinearSolve.DEFAULT_PRECS)}, NonlinearSolve.KlementUpdateRule, NonlinearSolve.IllConditionedJacobianReset, NonlinearSolve.IdentityInitialization{Nothing, NonlinearSolve.DiagonalStructure}}, NonlinearProblem{Matrix{Float64}, true, Tuple{Float64, Float64, Float64, Float64, Int64, Float64, Float64, Float64, Int64, Vararg{Float64, 5}}, NonlinearFunction{true, SciMLBase.FullSpecialize, typeof(ff_out_7), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing}, @Kwargs{abstol::Float64, reltol::Float64, maxiters::Int64}, SciMLBase.StandardNonlinearProblem}, NonlinearSolve.InitializedApproximateJacobianCache{Vector{Float64}, NonlinearSolve.DiagonalStructure, NonlinearSolve.IdentityInitialization{Nothing, NonlinearSolve.DiagonalStructure}, Nothing, typeof(NonlinearSolve.DEFAULT_NORM)}, NonlinearSolve.NewtonDescentCache{false, false, Matrix{Float64}, Nothing, NonlinearSolve.LinearSolverCache{Nothing, Nothing, Diagonal{Float64, Vector{Float64}}, Vector{Float64}, Nothing}, Nothing, Nothing, Nothing}, NonlinearSolve.NoLineSearchCache{Float64}, Nothing, NonlinearSolve.KlementUpdateRuleCache{Matrix{Float64}, Nothing, Nothing, Nothing, Matrix{Float64}}, NonlinearSolve.IllConditionedJacobianResetCache{Float64}, Nothing, Nothing, Nothing, DiffEqBase.NonlinearTerminationModeCache{false, AbsSafeBestTerminationMode{:Inf, Int64, Base.Fix1{typeof(maximum), typeof(abs)}, Nothing, Int64, Float64}, SciMLBase.ReturnCode.T, Matrix{Float64}, Float64, Float64, Float64, Float64, Vector{Float64}, Nothing, Nothing, Vector{Float64}, Int64, Matrix{Float64}}, NonlinearSolve.NonlinearSolveTrace{false, false, TraceMinimal, Nothing, NonlinearProblem{Matrix{Float64}, true, Tuple{Float64, Float64, Float64, Float64, Int64, Float64, Float64, Float64, Int64, Vararg{Float64, 5}}, NonlinearFunction{true, SciMLBase.FullSpecialize, typeof(ff_out_7), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing}, @Kwargs{abstol::Float64, reltol::Float64, maxiters::Int64}, SciMLBase.StandardNonlinearProblem}}}; recompute_jacobian::Nothing)
#
#     @ NonlinearSolve ~/.julia/packages/NonlinearSolve/R8LAH/src/core/approximate_jacobian.jl:304
#
#  [29] __step!
#
#     @ ~/.julia/packages/NonlinearSolve/R8LAH/src/core/approximate_jacobian.jl:221 [inlined]
#
#  [30] #step!#210
#
#     @ ~/.julia/packages/NonlinearSolve/R8LAH/src/core/generic.jl:55 [inlined]
#
#  [31] step!
#
#     @ ~/.julia/packages/NonlinearSolve/R8LAH/src/core/generic.jl:50 [inlined]
#
#  [32] solve!(cache::NonlinearSolve.ApproximateJacobianSolveCache{false, :LineSearch, true, false, Matrix{Float64}, Matrix{Float64}, Matrix{Float64}, Tuple{Float64, Float64, Float64, Float64, Int64, Float64, Float64, Float64, Int64, Vararg{Float64, 5}}, Matrix{Float64}, Diagonal{Float64, Vector{Float64}}, ApproximateJacobianSolveAlgorithm{false, :Klement, NoLineSearch, Missing, NewtonDescent{Nothing, typeof(NonlinearSolve.DEFAULT_PRECS)}, NonlinearSolve.KlementUpdateRule, NonlinearSolve.IllConditionedJacobianReset, NonlinearSolve.IdentityInitialization{Nothing, NonlinearSolve.DiagonalStructure}}, NonlinearProblem{Matrix{Float64}, true, Tuple{Float64, Float64, Float64, Float64, Int64, Float64, Float64, Float64, Int64, Vararg{Float64, 5}}, NonlinearFunction{true, SciMLBase.FullSpecialize, typeof(ff_out_7), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing}, @Kwargs{abstol::Float64, reltol::Float64, maxiters::Int64}, SciMLBase.StandardNonlinearProblem}, NonlinearSolve.InitializedApproximateJacobianCache{Vector{Float64}, NonlinearSolve.DiagonalStructure, NonlinearSolve.IdentityInitialization{Nothing, NonlinearSolve.DiagonalStructure}, Nothing, typeof(NonlinearSolve.DEFAULT_NORM)}, NonlinearSolve.NewtonDescentCache{false, false, Matrix{Float64}, Nothing, NonlinearSolve.LinearSolverCache{Nothing, Nothing, Diagonal{Float64, Vector{Float64}}, Vector{Float64}, Nothing}, Nothing, Nothing, Nothing}, NonlinearSolve.NoLineSearchCache{Float64}, Nothing, NonlinearSolve.KlementUpdateRuleCache{Matrix{Float64}, Nothing, Nothing, Nothing, Matrix{Float64}}, NonlinearSolve.IllConditionedJacobianResetCache{Float64}, Nothing, Nothing, Nothing, DiffEqBase.NonlinearTerminationModeCache{false, AbsSafeBestTerminationMode{:Inf, Int64, Base.Fix1{typeof(maximum), typeof(abs)}, Nothing, Int64, Float64}, SciMLBase.ReturnCode.T, Matrix{Float64}, Float64, Float64, Float64, Float64, Vector{Float64}, Nothing, Nothing, Vector{Float64}, Int64, Matrix{Float64}}, NonlinearSolve.NonlinearSolveTrace{false, false, TraceMinimal, Nothing, NonlinearProblem{Matrix{Float64}, true, Tuple{Float64, Float64, Float64, Float64, Int64, Float64, Float64, Float64, Int64, Vararg{Float64, 5}}, NonlinearFunction{true, SciMLBase.FullSpecialize, typeof(ff_out_7), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing}, @Kwargs{abstol::Float64, reltol::Float64, maxiters::Int64}, SciMLBase.StandardNonlinearProblem}}})
#
#     @ NonlinearSolve ~/.julia/packages/NonlinearSolve/R8LAH/src/core/generic.jl:13
#
#  [33] #__solve#209
#
#     @ ~/.julia/packages/NonlinearSolve/R8LAH/src/core/generic.jl:4 [inlined]
#
#  [34] __solve
#
#     @ ~/.julia/packages/NonlinearSolve/R8LAH/src/core/generic.jl:1 [inlined]
#
#  [35] macro expansion
#
#     @ ~/.julia/packages/NonlinearSolve/R8LAH/src/default.jl:278 [inlined]
#
#  [36] __solve(::NonlinearProblem{Matrix{Float64}, true, Tuple{Float64, Float64, Float64, Float64, Int64, Float64, Float64, Float64, Int64, Vararg{Float64, 5}}, NonlinearFunction{true, SciMLBase.FullSpecialize, typeof(ff_out_7), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing}, @Kwargs{abstol::Float64, reltol::Float64, maxiters::Int64}, SciMLBase.StandardNonlinearProblem}, ::NonlinearSolvePolyAlgorithm{:NLS, 7, Tuple{ApproximateJacobianSolveAlgorithm{false, :Broyden, NoLineSearch, Missing, NewtonDescent{Nothing, typeof(NonlinearSolve.DEFAULT_PRECS)}, NonlinearSolve.GoodBroydenUpdateRule, NonlinearSolve.NoChangeInStateReset{Nothing}, NonlinearSolve.IdentityInitialization{Nothing, NonlinearSolve.FullStructure}}, ApproximateJacobianSolveAlgorithm{true, :Broyden, NoLineSearch, Missing, NewtonDescent{Nothing, typeof(NonlinearSolve.DEFAULT_PRECS)}, NonlinearSolve.GoodBroydenUpdateRule, NonlinearSolve.NoChangeInStateReset{Nothing}, NonlinearSolve.TrueJacobianInitialization{NonlinearSolve.FullStructure, Nothing}}, ApproximateJacobianSolveAlgorithm{false, :Klement, NoLineSearch, Missing, NewtonDescent{Nothing, typeof(NonlinearSolve.DEFAULT_PRECS)}, NonlinearSolve.KlementUpdateRule, NonlinearSolve.IllConditionedJacobianReset, NonlinearSolve.IdentityInitialization{Nothing, NonlinearSolve.DiagonalStructure}}, GeneralizedFirstOrderAlgorithm{nothing, :NewtonRaphson, NoLineSearch, Missing, NewtonDescent{Nothing, typeof(NonlinearSolve.DEFAULT_PRECS)}, Nothing, Nothing, Nothing}, GeneralizedFirstOrderAlgorithm{nothing, :NewtonRaphson, LineSearchesJL{LineSearches.BackTracking{Float64, Int64}, Bool, Nothing}, Missing, NewtonDescent{Nothing, typeof(NonlinearSolve.DEFAULT_PRECS)}, Nothing, Nothing, Nothing}, GeneralizedFirstOrderAlgorithm{nothing, :TrustRegion, Missing, NonlinearSolve.GenericTrustRegionScheme{NonlinearSolve.RadiusUpdateSchemes.__Simple, Rational{Int64}, Rational{Int64}, Rational{Int64}, Rational{Int64}, Rational{Int64}, Nothing, Nothing, Nothing, Nothing}, Dogleg{NewtonDescent{Nothing, typeof(NonlinearSolve.DEFAULT_PRECS)}, SteepestDescent{Nothing, typeof(NonlinearSolve.DEFAULT_PRECS)}}, Nothing, Nothing, Nothing}, GeneralizedFirstOrderAlgorithm{nothing, :TrustRegion, Missing, NonlinearSolve.GenericTrustRegionScheme{NonlinearSolve.RadiusUpdateSchemes.__Bastin, Rational{Int64}, Rational{Int64}, Rational{Int64}, Rational{Int64}, Rational{Int64}, Nothing, Nothing, Nothing, Nothing}, Dogleg{NewtonDescent{Nothing, typeof(NonlinearSolve.DEFAULT_PRECS)}, SteepestDescent{Nothing, typeof(NonlinearSolve.DEFAULT_PRECS)}}, Nothing, Nothing, Nothing}}}; alias_u0::Bool, verbose::Bool, kwargs::@Kwargs{default_set::Bool, second_time::Bool, abstol::Float64, reltol::Float64, maxiters::Int64})
#
#     @ NonlinearSolve ~/.julia/packages/NonlinearSolve/R8LAH/src/default.jl:248
#
#  [37] __solve
#
#     @ ~/.julia/packages/NonlinearSolve/R8LAH/src/default.jl:248 [inlined]
#
#  [38] #__solve#329
#
#     @ ~/.julia/packages/NonlinearSolve/R8LAH/src/default.jl:511 [inlined]
#
#  [39] __solve
#
#     @ ~/.julia/packages/NonlinearSolve/R8LAH/src/default.jl:508 [inlined]
#
#  [40] #__solve#72
#
#     @ ~/.julia/packages/DiffEqBase/O8cUq/src/solve.jl:1394 [inlined]
#
#  [41] __solve
#
#     @ ~/.julia/packages/DiffEqBase/O8cUq/src/solve.jl:1386 [inlined]
#
#  [42] solve_call(::NonlinearProblem{Matrix{Float64}, true, Tuple{Float64, Float64, Float64, Float64, Int64, Float64, Float64, Float64, Int64, Vararg{Float64, 5}}, NonlinearFunction{true, SciMLBase.FullSpecialize, typeof(ff_out_7), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing}, @Kwargs{abstol::Float64, reltol::Float64, maxiters::Int64}, SciMLBase.StandardNonlinearProblem}; merge_callbacks::Bool, kwargshandle::Nothing, kwargs::@Kwargs{})
#
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/O8cUq/src/solve.jl:612
#
#  [43] solve_call
#
#     @ ~/.julia/packages/DiffEqBase/O8cUq/src/solve.jl:569 [inlined]
#
#  [44] #solve_up#53
#
#     @ ~/.julia/packages/DiffEqBase/O8cUq/src/solve.jl:1072 [inlined]
#
#  [45] solve_up
#
#     @ ~/.julia/packages/DiffEqBase/O8cUq/src/solve.jl:1066 [inlined]
#
#  [46] #solve#52
#
#     @ ~/.julia/packages/DiffEqBase/O8cUq/src/solve.jl:1060 [inlined]
#
#  [47] solve(::NonlinearProblem{Matrix{Float64}, true, Tuple{Float64, Float64, Float64, Float64, Int64, Float64, Float64, Float64, Int64, Vararg{Float64, 5}}, NonlinearFunction{true, SciMLBase.FullSpecialize, typeof(ff_out_7), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing}, @Kwargs{abstol::Float64, reltol::Float64, maxiters::Int64}, SciMLBase.StandardNonlinearProblem})
#
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/O8cUq/src/solve.jl:1050
#
#  [48] solve_out_7(Lx::Float64, Nx::Int64, ϕa::Float64, ϕp::Float64, v0::Float64, ind::Int64, γ::Float64, u0::Matrix{Float64}; tol::Float64, maxiters::Int64)
#
#     @ Main ~/Active_Lattice/pm_scripts/pm_figs/outer_ode_7.ipynb:48
#
#  [49] top-level scope
#
#     @ ~/Active_Lattice/pm_scripts/pm_figs/outer_ode_7.ipynb:5

# %%
ϕaL, ϕaR, ϕL, ϕR = get_BC(2.3,v0;initial_Δ = 1e-6, tol = 1e-8 )
# Out:
# no turn in g0
# no solution: output γ_max
# (0.6893274999999999, 0.6893274999999999, 0.8649249999999999, 0.8649249999999999)

# %%
Lx,Nx,ϕa,ϕp,v0,ind,γ = 100.0, 1024, 0.3, 0.3, 7.5, 52, 2.3
# Lx,Nx,ϕa,ϕp,v0,ind,γ = 100.0, 1024, 0.3, 0.3, 7.5, 800, 1.5
param, ps = get_outer_param_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
f,u,c = load_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ)
# f,u,c = solve_out_7(Lx,Nx,ϕa,ϕp,v0,ind,γ,u; tol = 1e-8, maxiters = 10)
# check densities
        ϕp = sum(f)/Nx-sum(f[:,1:2])/Nx
        if ϕp ≈ ( param["ϕp"] )
            ϕp = param["ϕp"]
        else
            ϕp = d2(ϕp)
        end
        ϕa = sum(f[:,1:2])/Nx
        if ϕa ≈ ( param["ϕa"] )
            ϕa = param["ϕa"]
        else
            ϕa = d2(ϕa)
        end
#
rhodiff = u[ind+1] - u[ind]
err, erri, avmag, cep = check_u_7(u,ps);
println("ϕa,ϕp=($(ϕa),$(ϕp)): rhodiff=$(rhodiff), c =$(c), avmag=$(avmag), err=$(err),$(erri), ind=$(ind)")
# Out:
# no turn in g0
# no solution: output γ_maxno turn in g0
# no solution: output γ_maxno turn in g0
# no solution: output γ_maxϕa,ϕp=(0.73,0.17): rhodiff=0.0, c =0.007851077917021608, avmag=-0.0011239840857478283, err=3.1600977390411344e-10,10, ind=52

# %%
ϕp = sum(f)/Nx-sum(f[:,1:2])/Nx
ϕa = sum(f[:,1:2])/Nx
ϕa,ϕp
# Out:
# (0.7266672955800195, 0.170635774264835)

# %%
# Lx, Nx, ϕa, ϕp, v0 = 100.0, 1024, 0.7266672955800195, 0.170635774264835, 7.5
ϕp = 0.1414
ϕa = get_active(ϕp; Pe = 7.5)+0.00075
Lx, Nx, ϕa, ϕp, v0 = 100.0, 1024, ϕa, ϕp, 7.5
param, p2 = get_outer_param_3(Lx,Nx,ϕa,ϕp,v0)
# try 
#     global f,u,c
    f,u,c = load_out_3(Lx,Nx,ϕa,ϕp,v0)
# catch
    # f,u,c = solve_out_3(Lx,Nx,ϕa,ϕp,v0,u; tol = 1e-8, maxiters = 10)
# end
err, avmag, c = check_u_3(u,p2);
ϕp = sum(f)/Nx-sum(f[:,1:2])/Nx
ϕa = sum(f[:,1:2])/Nx
normf = sqrt(sum( (f[:,1] .- ϕa/2).^2 + (f[:,2] .- ϕa/2).^2 + (f[:,3] .- ϕp).^2)/Nx)
print("ϕa,ϕp=($(ϕa),$(ϕp)): norm = $(normf), c=$(c), avmag=$(avmag), err=$(err)")

# %%
function get_active(ϕp; Pe = 7.5)
    f(x) = is_stable_value(x, ϕp; Pe = Pe)
    return find_zero(f,(0.5,1-ϕp-1e-8))
end

get_active(0.170635774264835; Pe = 7.5)

# %%
using PyPlot, LaTeXStrings
fig, axs = subplots(1,2,figsize=(10,5))
rc("text", usetex=true)
show_f(axs,fig,12,param,f; c=c, point = ind+Nx÷2)
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)
